# %%
import yfinance as yf
import mplfinance as mpf

# %%
ticker = "TSLA"

# %%
history = yf.Ticker(ticker).history(period="3mo")

# %%
print(f"3 months low: {history.Low.min().astype(int)}")
print(f"3 months high: {history.High.max().astype(int)}")
# Out:
# 3 months low: 152
# 3 months high: 261

# %%
history.tail()
# Out:
#                                  Open        High         Low       Close
# Date
# 2023-06-12 00:00:00-04:00  247.940002  250.970001  244.589996  249.830002  \
# 2023-06-13 00:00:00-04:00  253.509995  259.679993  251.339996  258.709991
# 2023-06-14 00:00:00-04:00  260.170013  261.570007  250.500000  256.790009
# 2023-06-15 00:00:00-04:00  248.399994  258.950012  247.289993  255.899994
# 2023-06-16 00:00:00-04:00  258.920013  261.437286  257.209991  260.700012
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-06-12 00:00:00-04:00  150337900        0.0           0.0
# 2023-06-13 00:00:00-04:00  162384300        0.0           0.0
# 2023-06-14 00:00:00-04:00  170575500        0.0           0.0
# 2023-06-15 00:00:00-04:00  159419000        0.0           0.0
# 2023-06-16 00:00:00-04:00   29418502        0.0           0.0

# %%
mpf.plot(history, type='candle', mav=(7),figratio=(18,10))
